# %% [markdown]
# # COURSE: Master statistics and machine learning: Intuition, Math, code
# ##### COURSE URL: udemy.com/course/statsml_x/?couponCode=202304
# ## SECTION: Visualizing data
# ### VIDEO: Box-and-whisker plots
# #### TEACHER: Mike X Cohen, sincxpress.com

# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
## create data for the bar plot

# data sizes
m = 30 # rows
n =  6 # columns

# generate data
data = np.zeros((m,n))

for i in range(n):
    data[:,i] = 30*np.random.randn(m) * (2*i/(n-1)-1)**2 + (i+1)**2

# %%
# now for the boxplot

plt.boxplot(data)
plt.show()

# %%
# now with seaborn
sns.boxplot(data=data,orient='v')
plt.show()

# %%
# or as a pandas data frame
df = pd.DataFrame(data,columns=['zero','one','two','three','four','five'])
sns.boxplot(data=df,orient='h')
plt.show()

# %%
np.random.randint(1,10,(10,10))
# Out:
# array([[3, 3, 6, 1, 8, 6, 7, 2, 6, 1],
#        [6, 5, 1, 3, 9, 3, 2, 9, 4, 7],
#        [8, 8, 8, 3, 4, 4, 4, 1, 7, 7],
#        [1, 4, 3, 4, 7, 7, 5, 2, 6, 8],
#        [8, 8, 2, 2, 9, 3, 5, 3, 3, 9],
#        [4, 8, 9, 2, 6, 1, 9, 7, 8, 3],
#        [9, 4, 3, 4, 7, 8, 2, 1, 1, 8],
#        [9, 1, 1, 5, 6, 7, 3, 3, 8, 8],
#        [6, 3, 9, 1, 3, 1, 5, 9, 7, 4],
#        [7, 7, 8, 1, 5, 1, 3, 2, 2, 9]])

# %%
xx = np.random.random((10,10))
yy = (np.trunc(xx*100)+1).astype(int)
yy
# Out:
# array([[  2,  76,  49,  42,  73,  41,  40,  41,  79,  42],
#        [ 43,  94,  29,  15,  49,  39,   5,  86,  17,  71],
#        [ 74,  86,  55,  99, 100,  37,  37,  49,  96,   7],
#        [ 21,  60,  95,  45,  43,  79,  46,   5,  27,  11],
#        [ 26,  10,  93,  14,  85,  17,  29,  47,  12,  44],
#        [  3,  95,  80,  25,  21,  15,  91,   8,  49,  35],
#        [ 47,  23,  94,  32,  60,  77,  14,   8,  67,  34],
#        [ 85,  50,  10,  56,  45,  86,  39,  69,  59,   9],
#        [ 77,  95,  56,  17,  59,  16,  30,  18,   6,  78],
#        [ 67,  15,  53,  37,  85,  69,  23,  17,  40,  20]])

# %%
np.random.choice(yy.flatten(),(5,5))
# Out:
# array([[17, 40,  3, 20, 46],
#        [37, 23, 11, 35, 15],
#        [37, 56, 29, 55,  9],
#        [47, 69, 37, 14, 18],
#        [67, 43, 14,  9, 56]])

# %%
from numpy import random

x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(3, 5))

print(x)
# Out:
# [[7 5 3 7 7]
#  [5 7 5 3 7]
#  [7 7 7 7 5]]

# %%
random.permutation(x)
# Out:
# array([[7, 7, 7, 7, 5],
#        [7, 5, 3, 7, 7],
#        [5, 7, 5, 3, 7]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5])

plt.show()
# Out:
# /var/folders/nb/z1y20j114lz923_5rgsb14h80000gn/T/ipykernel_16164/174120514.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

plt.show()
# Out:
# /var/folders/nb/z1y20j114lz923_5rgsb14h80000gn/T/ipykernel_16164/2406393504.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

# %%
np.random.normal(1,100,100)
# Out:
# array([ 2.05907438e+01, -1.28319211e+01, -5.58994298e+01, -1.09815293e+02,
#        -1.71798272e+01,  7.08073338e+01, -7.26304526e+00,  9.88005098e+00,
#        -1.01329317e+02,  1.16352811e+02,  1.08856065e+02,  2.71211821e+01,
#         1.31481538e+01,  1.65670398e+02,  1.52968280e+01,  8.95333969e+01,
#         1.76242745e+01,  9.84198812e+01,  8.24794203e+01, -8.04603279e+00,
#         7.56320619e+00, -7.44037114e+01, -8.03170490e+01, -5.36109036e+00,
#         7.03257188e+01,  4.90666730e+01, -1.10988765e+01,  7.37356205e+01,
#         6.26893134e+01,  7.24884417e+01, -6.47399394e+01, -3.23423593e+01,
#        -3.41153379e+01, -1.19816004e+01,  4.65556277e+01,  1.30175927e+01,
#         1.04838912e+02, -9.01303777e+01,  6.28449727e-01,  1.20624912e+02,
#         4.05018608e+01, -2.25971112e+02,  8.77011769e+01, -6.89975528e+01,
#         5.89531660e+01, -2.63385959e+01, -2.82036152e+02,  2.85958059e+00,
# ...

# %%
plt.hist(np.random.normal(1,100,600))
# Out:
# (array([  5.,  17.,  57., 133., 157., 124.,  74.,  25.,   7.,   1.]),
#  array([-315.12681268, -245.24066452, -175.35451636, -105.4683682 ,
#          -35.58222003,   34.30392813,  104.19007629,  174.07622446,
#          243.96237262,  313.84852078,  383.73466894]),
#  <BarContainer object of 10 artists>)
